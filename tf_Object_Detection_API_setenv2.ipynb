# %% [markdown]
# **環境設定**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %tensorflow_version 2.x
# !pip uninstall -y tensorflow
# !pip install tensorflow==1.15
# !pip install tensorflow-gpu==1.14
# Out:
# Found existing installation: tensorflow 2.7.0
# Uninstalling tensorflow-2.7.0:
#   Successfully uninstalled tensorflow-2.7.0
# ...
#      |████████████████████████████████| 412.3 MB 26 kB/s
# ...
#      |████████████████████████████████| 3.8 MB 34.1 MB/s
# ...
#      |████████████████████████████████| 503 kB 55.8 MB/s
# ...
#      |████████████████████████████████| 50 kB 6.1 MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=e67f2937d10373ef32e13f0405bba480d4fce3e0cbd7b778f64edebfd4d7eb96
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.7.0
#     Uninstalling tensorflow-estimator-2.7.0:
#       Successfully uninstalled tensorflow-estimator-2.7.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.7.0
#     Uninstalling tensorboard-2.7.0:
# ...

# %% [markdown]
# **TFモデルとCOCO APIのダウンロード（していなければ）**

# %%
# %cd /content/drive/MyDrive/後期/きゅうり10/TF/
# TFモデルのダウンロード
# !git clone https://github.com/tensorflow/models.git
# COCO APIのダウンロード
# !git clone https://github.com/cocodataset/cocoapi.git
# %cd cocoapi/PythonAPI
# !make
# !cp -r pycocotools /content/drive/MyDrive/後期/きゅうり10/TF/models/research/
# Out:
# /content/drive/MyDrive/後期/きゅうり10/TF
# fatal: destination path 'models' already exists and is not an empty directory.
# fatal: destination path 'cocoapi' already exists and is not an empty directory.
# /content/drive/MyDrive/後期/きゅうり10/TF/cocoapi/PythonAPI
# python setup.py build_ext --inplace
# running build_ext
# skipping 'pycocotools/_mask.c' Cython extension (up-to-date)
# building 'pycocotools._mask' extension
# creating build
# creating build/common
# creating build/temp.linux-x86_64-3.7
# creating build/temp.linux-x86_64-3.7/pycocotools
# ...

# %% [markdown]
# # **紐づけ（毎回必要っぽい）**

# %%
# %cd /content/drive/MyDrive/後期/きゅうり10/TF/models/research
# !protoc object_detection/protos/*.proto --python_out=.
# Out:
# /content/drive/MyDrive/後期/きゅうり10/TF/models/research

# %%
# %cd /content/drive/MyDrive/後期/きゅうり10/TF/models/research
# %env PYTHONPATH=/env/python:/content/drive/MyDrive/後期/きゅうり10/TF/models/research/:/content/drive/MyDrive/後期/きゅうり10/TF/models/research/slim
# %env
# !python object_detection/builders/model_builder_test.py
# Out:
# /content/drive/MyDrive/後期/きゅうり10/TF/models/research
# env: PYTHONPATH=/env/python:/content/drive/MyDrive/後期/きゅうり10/TF/models/research/:/content/drive/MyDrive/後期/きゅうり10/TF/models/research/slim
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# ...

# %% [markdown]
# **学習**

# %%
# !python /content/drive/MyDrive/後期/きゅうり10/TF/models/research/object_detection/model_main.py --pipeline_config_path=/content/drive/MyDrive/後期/きゅうり10/Log/log_SSD/ssd_inception_v2_pets.config --model_dir /content/drive/MyDrive/後期/きゅうり10/保存 --alsologtostderr
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !python /content/drive/MyDrive/後期/きゅうり10/TF/models/research/object_detection/export_inference_graph.py --input_type image_tensor --pipeline_config_path /content/drive/MyDrive/後期/きゅうり10/Log/log_SSD/ssd_inception_v2_pets.config --trained_checkpoint_prefix /content/drive/MyDrive/後期/きゅうり10/保存/model.ckpt-20000 --output_directory /content/drive/MyDrive/後期/きゅうり10/保存/infarence_graph
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
